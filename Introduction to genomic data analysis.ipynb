# %% [markdown]
# ## 0.-  Get data

# %% [markdown]
# ### Install libraries

# %%
# %pip install bioframe
# Out:
# Python interpreter will be restarted.
# Requirement already satisfied: bioframe in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ebf931f3-08d5-4932-87fe-e254e5b64bec/lib/python3.9/site-packages (0.4.0)
# Requirement already satisfied: matplotlib in /databricks/python3/lib/python3.9/site-packages (from bioframe) (3.4.3)
# Requirement already satisfied: numpy>=1.10 in /databricks/python3/lib/python3.9/site-packages (from bioframe) (1.20.3)
# Requirement already satisfied: pandas>=1.3 in /databricks/python3/lib/python3.9/site-packages (from bioframe) (1.3.4)
# Requirement already satisfied: requests in /databricks/python3/lib/python3.9/site-packages (from bioframe) (2.26.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /databricks/python3/lib/python3.9/site-packages (from pandas>=1.3->bioframe) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /databricks/python3/lib/python3.9/site-packages (from pandas>=1.3->bioframe) (2021.3)
# Requirement already satisfied: six>=1.5 in /databricks/python3/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas>=1.3->bioframe) (1.16.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /databricks/python3/lib/python3.9/site-packages (from matplotlib->bioframe) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /databricks/python3/lib/python3.9/site-packages (from matplotlib->bioframe) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in /databricks/python3/lib/python3.9/site-packages (from matplotlib->bioframe) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in /databricks/python3/lib/python3.9/site-packages (from matplotlib->bioframe) (8.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.9/site-packages (from requests->bioframe) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /databricks/python3/lib/python3.9/site-packages (from requests->bioframe) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /databricks/python3/lib/python3.9/site-packages (from requests->bioframe) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.9/site-packages (from requests->bioframe) (2021.10.8)
# Python interpreter will be restarted.

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import bioframe
import glob
import os

# %% [markdown]
# ### Functions

# %%
def download_data(url_list: list, path: str):
    """
    Download files from website
        param:
            - url_list: List url of files 
            - path: Where save files downloading
        return:
            None
    """
    for url in url_list:
        os.system(f"""(cd {path} && curl -O -L {url})""")

# %%
def get_name_file_from_folder(path: str):
    """
    Get the full path of the files in the folder
        param:
            - path: Path folder
    return:
        - A list with full path of the files in the folder
    """
    return glob.glob(path+"/*")

# %% [markdown]
# [All schemas](https://github.com/open2c/bioframe/blob/main/bioframe/io/schemas.py)

# %%
def create_dataframe(path_files: str, schema_name="bed9"):
    """
    Concat all data of files in the folder
        param:
            - path_files: A list with full path of the files in the folder
            - schema_name: Data schema you need
        return:
            - A pandas dataframe with all data of files in the folder
    """
    df_aux = pd.DataFrame()
    for file in path_files:
        df = bioframe.read_table(
            file,
            schema=schema_name
            )
        df_aux = pd.concat([df_aux, df])
    return df_aux.reset_index()

# %% [markdown]
# ### Create spark dataframe HDFs

# %%
def create_spark_dataframe(df: pd.DataFrame):
    """
    Transform pandas dataframe to spark dataframe
        param:
            - df: Pandas dataframe you need to transform
    return:
        - A spark to dataframe
    """
    spark_dataframe = spark.createDataFrame(df)
    return spark_dataframe

# %% [markdown]
# ### Save table spark dataframe

# %%
def save_table(spark_dataframe, table_name: str, temp_table=""):
    """
    Save spark dataframe in delta table, parquet and temporary table
        param:
            - spark_dataframe: Spark dataframe you need to transform
            - table_name: Name to save the table
            - temp_table: Name to save the temporary table by 
                          default is saved with the name of the table
    """
    if temp_table == "":
        temp_table = table_name
    spark_dataframe.createOrReplaceTempView(temp_table)
    spark_dataframe.write.format("delta").mode("overwrite").save(f"/user/hive/warehouse/data/{table_name}")
    #Best practice save all data or dimensions in a parquet file
    spark_dataframe.repartition(1).write.format('parquet').mode('overwrite').save(f"data/dimensions")

# %% [markdown]
# ### Process
# * Download data
# * Decompress data

# %% [markdown]
# ### Create a folder

# %%
# %sh 
mkdir data/
mkdir data/genomics/
mkdir data/genomics/chip-seq
mkdir data/genomics/dnase

# %% [markdown]
# ### Download the DNase data

# %%
url_dnase_list = [
    "https://www.encodeproject.org/files/ENCFF001UVC/@@download/ENCFF001UVC.bed.gz",
    "https://www.encodeproject.org/files/ENCFF001UWQ/@@download/ENCFF001UWQ.bed.gz",
    "https://www.encodeproject.org/files/ENCFF001WEI/@@download/ENCFF001WEI.bed.gz",
    "https://www.encodeproject.org/files/ENCFF001UVQ/@@download/ENCFF001UVQ.bed.gz",
    "https://www.encodeproject.org/files/ENCFF001SOM/@@download/ENCFF001SOM.bed.gz",
    "https://www.encodeproject.org/files/ENCFF001UVU/@@download/ENCFF001UVU.bed.gz"
]
PATH_DNASE = "data/genomics/dnase"

# %%
download_data(url_dnase_list, PATH_DNASE)
# !ls data/genomics/dnase
# Out:
# ENCFF001SOM.bed.gz  ENCFF001UVQ.bed.gz	ENCFF001UWQ.bed.gz
# ENCFF001UVC.bed.gz  ENCFF001UVU.bed.gz	ENCFF001WEI.bed.gz

# %% [markdown]
# ### Download the ChIP-seq

# %%
url_chip_seq_list = [
    "https://www.encodeproject.org/files/ENCFF001VED/@@download/ENCFF001VED.bed.gz",
    "https://www.encodeproject.org/files/ENCFF001VMZ/@@download/ENCFF001VMZ.bed.gz",
    "https://www.encodeproject.org/files/ENCFF001XMU/@@download/ENCFF001XMU.bed.gz",
    "https://www.encodeproject.org/files/ENCFF001XQU/@@download/ENCFF001XQU.bed.gz",
    "https://www.encodeproject.org/files/ENCFF001USC/@@download/ENCFF001USC.bed.gz",
    "https://www.encodeproject.org/files/ENCFF001XRC/@@download/ENCFF001XRC.bed.gz",
]
PATH_CHIP_SEQ = "data/genomics/chip-seq"

# %%
download_data(url_chip_seq_list, PATH_CHIP_SEQ)
# !ls data/genomics/chip-seq
# Out:
# ENCFF001USC.bed.gz  ENCFF001VMZ.bed.gz	ENCFF001XQU.bed.gz
# ENCFF001VED.bed.gz  ENCFF001XMU.bed.gz	ENCFF001XRC.bed.gz

# %% [markdown]
# ### Create dataframe

# %%
path_files_chip_seq = get_name_file_from_folder(PATH_CHIP_SEQ)
path_files_dnase = get_name_file_from_folder(PATH_DNASE)

# %%
df_chip_seq = create_dataframe(path_files_chip_seq)
df_dnase = create_dataframe(path_files_dnase)
# Out:
# /databricks/python/lib/python3.9/site-packages/pandas/util/_decorators.py:311: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   return func(*args, **kwargs)

# %%
spark_dnase = create_spark_dataframe(df_dnase) 
spark_chip_seq =  create_spark_dataframe(df_chip_seq)

# %%
# Create a hdfs table, temp table and parquet
save_table(spark_dnase, "dnase", "temp_dnase") 
save_table(spark_chip_seq, "chip_seq", "temp_chip_seq")

# %% [markdown]
# ## 1.- View data

# %% [markdown]
# ### View tables

# %%
# %sql
SHOW TABLES;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>default</td><td>dnase</td><td>false</td></tr><tr><td></td><td>temp_chip_seq</td><td>true</td></tr><tr><td></td><td>temp_dnase</td><td>true</td></tr></tbody></table></div>

# %% [markdown]
# ### Basic queries (SQL)

# %%
# %sql
SELECT * FROM temp_chip_seq
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>index</th><th>chrom</th><th>start</th><th>end</th><th>name</th><th>score</th><th>strand</th><th>thickStart</th><th>thickEnd</th><th>rgb</th></tr></thead><tbody><tr><td>0</td><td>chrX</td><td>10087209</td><td>10088161</td><td>.</td><td>1000</td><td>.</td><td>91.15329</td><td>300.0</td><td>300.0</td></tr><tr><td>1</td><td>chr12</td><td>32907970</td><td>32909598</td><td>.</td><td>1000</td><td>.</td><td>76.52205</td><td>300.0</td><td>300.0</td></tr><tr><td>2</td><td>chr12</td><td>50360675</td><td>50361606</td><td>.</td><td>1000</td><td>.</td><td>149.86319</td><td>300.0</td><td>300.0</td></tr><tr><td>3</td><td>chr12</td><td>56617729</td><td>56618612</td><td>.</td><td>1000</td><td>.</td><td>180.71755</td><td>300.0</td><td>300.0</td></tr><tr><td>4</td><td>chr12</td><td>82751977</td><td>82753177</td><td>.</td><td>1000</td><td>.</td><td>108.63797</td><td>300.0</td><td>300.0</td></tr><tr><td>5</td><td>chr12</td><td>122231602</td><td>122233291</td><td>.</td><td>1000</td><td>.</td><td>122.64868</td><td>300.0</td><td>300.0</td></tr><tr><td>6</td><td>chr11</td><td>189544</td><td>190474</td><td>.</td><td>1000</td><td>.</td><td>118.98055</td><td>300.0</td><td>300.0</td></tr><tr><td>7</td><td>chr11</td><td>58938845</td><td>58939735</td><td>.</td><td>1000</td><td>.</td><td>138.27267</td><td>300.0</td><td>300.0</td></tr><tr><td>8</td><td>chr11</td><td>62553854</td><td>62555271</td><td>.</td><td>1000</td><td>.</td><td>136.69627</td><td>300.0</td><td>300.0</td></tr><tr><td>9</td><td>chr11</td><td>64780906</td><td>64782157</td><td>.</td><td>1000</td><td>.</td><td>189.39302</td><td>300.0</td><td>300.0</td></tr><tr><td>10</td><td>chr11</td><td>94884117</td><td>94885485</td><td>.</td><td>1000</td><td>.</td><td>97.15762</td><td>300.0</td><td>300.0</td></tr><tr><td>11</td><td>chr11</td><td>118560416</td><td>118561259</td><td>.</td><td>1000</td><td>.</td><td>204.69186</td><td>300.0</td><td>300.0</td></tr><tr><td>12</td><td>chr10</td><td>71905146</td><td>71907116</td><td>.</td><td>1000</td><td>.</td><td>74.68619</td><td>300.0</td><td>300.0</td></tr><tr><td>13</td><td>chr10</td><td>90694539</td><td>90695655</td><td>.</td><td>1000</td><td>.</td><td>120.08608</td><td>300.0</td><td>300.0</td></tr><tr><td>14</td><td>chr17</td><td>8286405</td><td>8287223</td><td>.</td><td>1000</td><td>.</td><td>214.70381</td><td>300.0</td><td>300.0</td></tr><tr><td>15</td><td>chr17</td><td>39804097</td><td>39805278</td><td>.</td><td>1000</td><td>.</td><td>165.04069</td><td>300.0</td><td>300.0</td></tr><tr><td>16</td><td>chr17</td><td>44270087</td><td>44272817</td><td>.</td><td>1000</td><td>.</td><td>53.24314</td><td>300.0</td><td>300.0</td></tr><tr><td>17</td><td>chr16</td><td>2389943</td><td>2391233</td><td>.</td><td>1000</td><td>.</td><td>625.85558</td><td>300.0</td><td>300.0</td></tr><tr><td>18</td><td>chr16</td><td>30103139</td><td>30104236</td><td>.</td><td>1000</td><td>.</td><td>111.99521</td><td>300.0</td><td>300.0</td></tr><tr><td>19</td><td>chr16</td><td>47176422</td><td>47178603</td><td>.</td><td>1000</td><td>.</td><td>177.43554</td><td>300.0</td><td>300.0</td></tr><tr><td>20</td><td>chr16</td><td>50840012</td><td>50840847</td><td>.</td><td>1000</td><td>.</td><td>81.69062</td><td>300.0</td><td>300.0</td></tr><tr><td>21</td><td>chr16</td><td>67554862</td><td>67555810</td><td>.</td><td>1000</td><td>.</td><td>209.35052</td><td>300.0</td><td>300.0</td></tr><tr><td>22</td><td>chr15</td><td>22460855</td><td>22462631</td><td>.</td><td>1000</td><td>.</td><td>338.97681</td><td>300.0</td><td>300.0</td></tr><tr><td>23</td><td>chr15</td><td>45749661</td><td>45751354</td><td>.</td><td>1000</td><td>.</td><td>64.67525</td><td>300.0</td><td>300.0</td></tr><tr><td>24</td><td>chr15</td><td>91474816</td><td>91476084</td><td>.</td><td>1000</td><td>.</td><td>72.32558</td><td>300.0</td><td>300.0</td></tr><tr><td>25</td><td>chr14</td><td>23025173</td><td>23026504</td><td>.< ...

# %%
# %sql
SELECT chrom, COUNT(chrom) AS num_chrom
FROM temp_dnase
GROUP BY chrom
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>chrom</th><th>num_chrom</th></tr></thead><tbody><tr><td>chr1</td><td>82014</td></tr><tr><td>chr10</td><td>38543</td></tr><tr><td>chr12</td><td>37211</td></tr><tr><td>chr13</td><td>18415</td></tr><tr><td>chr11</td><td>41197</td></tr><tr><td>chr14</td><td>22958</td></tr><tr><td>chr15</td><td>25177</td></tr><tr><td>chr17</td><td>44830</td></tr><tr><td>chr16</td><td>33722</td></tr><tr><td>chr2</td><td>59964</td></tr><tr><td>chr19</td><td>37976</td></tr><tr><td>chr18</td><td>14495</td></tr><tr><td>chr20</td><td>25652</td></tr><tr><td>chr22</td><td>21428</td></tr><tr><td>chr21</td><td>11207</td></tr><tr><td>chr4</td><td>28202</td></tr><tr><td>chr3</td><td>44916</td></tr><tr><td>chr6</td><td>42375</td></tr><tr><td>chr5</td><td>39535</td></tr><tr><td>chr7</td><td>43346</td></tr><tr><td>chr9</td><td>36396</td></tr><tr><td>chrX</td><td>20291</td></tr><tr><td>chr8</td><td>31875</td></tr><tr><td>chrY</td><td>474</td></tr></tbody></table></div>

# %%
# %sql
SELECT name, COUNT(chrom)
FROM temp_dnase
GROUP BY name
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>count(chrom)</th></tr></thead><tbody><tr><td>chr1.258</td><td>4</td></tr><tr><td>chr1.561</td><td>4</td></tr><tr><td>chr1.707</td><td>4</td></tr><tr><td>chr1.822</td><td>4</td></tr><tr><td>chr1.1121</td><td>4</td></tr><tr><td>chr1.1214</td><td>4</td></tr><tr><td>chr1.1280</td><td>4</td></tr><tr><td>chr1.1473</td><td>4</td></tr><tr><td>chr1.1498</td><td>4</td></tr><tr><td>chr1.2653</td><td>4</td></tr><tr><td>chr1.3146</td><td>4</td></tr><tr><td>chr1.3279</td><td>4</td></tr><tr><td>chr1.3590</td><td>4</td></tr><tr><td>chr1.3935</td><td>4</td></tr><tr><td>chr1.4087</td><td>4</td></tr><tr><td>chr1.4197</td><td>4</td></tr><tr><td>chr1.4946</td><td>4</td></tr><tr><td>chr1.4983</td><td>4</td></tr><tr><td>chr1.5069</td><td>4</td></tr><tr><td>chr1.5584</td><td>4</td></tr><tr><td>chr1.5799</td><td>4</td></tr><tr><td>chr1.6039</td><td>4</td></tr><tr><td>chr1.6179</td><td>4</td></tr><tr><td>chr1.6349</td><td>4</td></tr><tr><td>chr1.6668</td><td>4</td></tr><tr><td>chr1.6695</td><td>4</td></tr><tr><td>chr1.6836</td><td>4</td></tr><tr><td>chr1.7117</td><td>4</td></tr><tr><td>chr1.7270</td><td>4</td></tr><tr><td>chr1.7372</td><td>4</td></tr><tr><td>chr1.7627</td><td>4</td></tr><tr><td>chr1.7657</td><td>4</td></tr><tr><td>chr1.7689</td><td>4</td></tr><tr><td>chr1.7700</td><td>4</td></tr><tr><td>chr1.8093</td><td>4</td></tr><tr><td>chr1.8310</td><td>4</td></tr><tr><td>chr1.8548</td><td>4</td></tr><tr><td>chr1.9019</td><td>4</td></tr><tr><td>chr1.9042</td><td>4</td></tr><tr><td>chr1.9664</td><td>4</td></tr><tr><td>chr1.9902</td><td>4</td></tr><tr><td>chr1.9993</td><td>4</td></tr><tr><td>chr1.234</td><td>4</td></tr><tr><td>chr1.586</td><td>4</td></tr><tr><td>chr1.706</td><td>4</td></tr><tr><td>chr1.1065</td><td>4</td></tr><tr><td>chr1.1099</td><td>4</td></tr><tr><td>chr1.1284</td><td>4</td></tr><tr><td>chr1.1645</td><td>4</td></tr><tr><td>chr1.1671</td><td>4</td></tr><tr><td>chr1.1704</td><td>4</td></tr><tr><td>chr1.1822</td><td>4</td></tr><tr><td>chr1.2014</td><td>4</td></tr><tr><td>chr1.2523</td><td>4</td></tr><tr><td>chr1.2962</td><td>4</td></tr><tr><td>chr1.3251</td><td>4</td></tr><tr><td>chr1.3376</td><td>4</td></tr><tr><td>chr1.3410</td><td>4</td></tr><tr><td>chr1.3832</td><td>4</td></tr><tr><td>chr1.4406</td><td>4</td></tr><tr><td>chr1.4537</td><td>4</td></tr><tr><td>chr1.4555</td><td>4</td></tr><tr><td>chr1.4847</td><td>4</td></tr><tr><td>chr1.4924</td><td>4</td></tr><tr><td>chr1.5018</td><td>4</td></tr><tr><td>chr1.5511</td><td>4</td></tr><tr><td>chr1.5554</td><td>4</td></tr><tr><td>chr1.5654</td><td>4</td></tr><tr><td>chr1.5702</td><td>4</td></tr><tr><td>chr1.5943</td><td>4</td></tr><tr><td>chr1.5999</td><td>4</td></tr><tr><td>chr1.6386</td><td>4</td></tr><tr><td>chr1.6522</td><td>4</td></tr><tr><td>chr1.6552</td><td>4</td></tr><tr><td>chr1.6554</td><td>4</td></tr><tr><td>chr1.6796</td><td>4</td></tr><tr><td>chr1.7143</td><td>4</td></tr><tr><td>chr1.7425</td><td>4</td></tr><tr><td>chr1.7483</td><td>4</td></tr><tr><td>chr1.7532</td><td>4</td></tr><tr><td>chr1.7707</td><td>4</td></tr><tr><td>chr1.7744</td><td>4</td></tr><tr><td>chr1.7829</td><td>4</td></tr><tr><td>chr1.7989</td><td>4</td></tr><tr><td>chr1.8058</td><td>4</td></tr><tr><td>chr1.8547</td><td>4</td></tr><tr><td>chr1.8824</td><td>4</td></tr><tr><td>chr1.9020</td><td>4</td></tr><tr><td>chr1.9614</td><td>4</td></tr><tr><td>chr1.9777</td><td>4</td></tr><tr><td>chr1.9971</td><td>4</td></tr><tr><td>chr1.5638</td><td>4</td></tr><tr><td>chr1.8237</td><td>4</td></tr><tr><td>chr1.7</td><td>4</td></tr><tr><td>chr1.108</td><td>4</td></tr><tr><td>chr1.142</td><td>4</td></tr><tr><td>chr1.223</td><td>4</td></tr><tr><td>chr1.237</td><td>4</td></tr><tr><td>chr1.681</td><td>4</td></tr><tr><td>chr1.947</td><td>4</td></tr><tr><td>chr1.1079</td><td>4</td></tr><tr><td>chr1.1160</td><td>4</td></tr><tr><td>chr1.1164</td><td>4</td></tr><tr><td>chr1.1206</td><td>4</td></tr ...

# %%
# %sql
SELECT COUNT(distinct name) AS total_name
FROM temp_dnase
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_name</th></tr></thead><tbody><tr><td>137628</td></tr></tbody></table></div>

# %% [markdown]
# ### Basic queries (Spark_SQL)

# %%
spark.sql("""
SELECT
    chrom,
    start,
    end,
    name
FROM
    temp_dnase
""").show()
# Out:
# +-----+------+------+-------+
# |chrom| start|   end|   name|
# +-----+------+------+-------+
# | chr1|713835|714424| chr1.1|
# | chr1|752775|753050| chr1.2|
# | chr1|753373|753448| chr1.3|
# | chr1|762057|763210| chr1.4|
# | chr1|793358|793612| chr1.5|
# | chr1|805101|805538| chr1.6|
# | chr1|839626|840461| chr1.7|
# | chr1|842125|842534| chr1.8|
# | chr1|846334|846381| chr1.9|
# | chr1|846545|846937|chr1.10|
# | chr1|848219|848588|chr1.11|
# | chr1|851784|852887|chr1.12|
# | chr1|853228|853414|chr1.13|
# | chr1|856335|856934|chr1.14|
# | chr1|858910|861473|chr1.15|
# | chr1|864323|864424|chr1.16|
# | chr1|866939|867506|chr1.17|
# | chr1|867659|867895|chr1.18|
# | chr1|868382|868481|chr1.19|
# | chr1|868918|869332|chr1.20|
# +-----+------+------+-------+
# only showing top 20 rows

# %%
spark.sql("""
SELECT
    chrom,
    start,
    end,
    name
FROM
    temp_dnase
ORDER BY chrom DESC
""").show()
# Out:
# +-----+-------+-------+-------+
# |chrom|  start|    end|   name|
# +-----+-------+-------+-------+
# | chrY|2685240|2685390|      .|
# | chrY|2655336|2655515| chrY.1|
# | chrY|7242660|7242810|      .|
# | chrY|4859732|4860163|chrY.21|
# | chrY|2689760|2689910|      .|
# | chrY|2655752|2655873| chrY.2|
# | chrY|2709520|2709670|      .|
# | chrY|2657974|2658081| chrY.3|
# | chrY|2725840|2725990|      .|
# | chrY|2665305|2665362| chrY.4|
# | chrY|2727940|2728090|      .|
# | chrY|2706083|2706297| chrY.5|
# | chrY|2728720|2728870|      .|
# | chrY|2709507|2709878| chrY.6|
# | chrY|2742420|2742570|      .|
# | chrY|2725845|2725944| chrY.7|
# | chrY|2755600|2755750|      .|
# | chrY|2781305|2781396| chrY.8|
# | chrY|2756120|2756270|      .|
# | chrY|2802876|2804346| chrY.9|
# +-----+-------+-------+-------+
# only showing top 20 rows

# %%
spark.sql("""
SELECT
    *
FROM
    temp_chip_seq
-- WHERE rgb < 300 AND rgb > 100
ORDER BY rgb ASC
""").show()
# Out:
# +-----+-----+---------+---------+----------+-----+------+----------+--------+----+
# |index|chrom|    start|      end|      name|score|strand|thickStart|thickEnd| rgb|
# +-----+-----+---------+---------+----------+-----+------+----------+--------+----+
# | 9180|chr11| 64110000| 64110150|         .|    0|     .|      25.0| 12.2144|-1.0|
# |    9| chr1|   840100|   840250|         .|    0|     .|      38.0| 41.7674|-1.0|
# |   18| chr1|   994800|   994950|         .|    0|     .|       8.0|  6.9648|-1.0|
# |   29| chr1|  1058380|  1058530|         .|    0|     .|       8.0| 5.05584|-1.0|
# |20766|chr15| 84506758| 84507040|chr15.1757| 1000|     .|    1.0336|    16.0|-1.0|
# |   10| chr1|   848340|   848490|         .|    0|     .|      14.0| 10.3093|-1.0|
# |   38| chr1|  1376380|  1376530|         .|    0|     .|      74.0| 120.708|-1.0|
# |   13| chr1|   860360|   860510|         .|    0|     .|      13.0| 11.8292|-1.0|
# |19323|chr17| 65830120| 65830270|         .|    0|     .|      11.0|   13.08|-1.0|
# |   28| chr1|  1057560|  1057710|         .|    0|     .|     152.0| 183.762|-1.0|
# |   19| chr1|   999260|   999410|         .|    0|     .|      43.0| 60.2348|-1.0|
# |   14| chr1|   861020|   861170|         .|    0|     .|      14.0| 10.5799|-1.0|
# |20767|chr15| 84642658| 84642887|chr15.1758|  660|     .|    0.3578|    7.56|-1.0|
# |   15| chr1|   867000|   867150|         .|    0|     .|       8.0| 4.71983|-1.0|
# |    0| chr1|    91440|    91590|         .|    0|     .|       4.0| 4.48323|-1.0|
# |   16| chr1|   873580|   873730|         .|    0|     .|      76.0|  90.166|-1.0|
# |17433|chr14|102680740|102680890|         .|    0|     .|       9.0| 5.05584|-1.0|
# |    0| chr1|    91440|    91590|         .|    0|     .|      25.0| 4.30801|-1.0|
# |   20| chr1|  1057600|  1057750|         .|    0|     .|      51.0| 65.9837|-1.0|
# |   17| chr1|   886860|   887010|         .|    0|     .|      26.0| 32.5662|-1.0|
# +-----+-----+---------+---------+----------+-----+------+----------+--------+----+
# only showing top 20 rows

# %% [markdown]
# ### Basic queries (PySpark)

# %%
spark_dnase.select("chrom","index").show(5)
# Out:
# +-----+-----+
# |chrom|index|
# +-----+-----+
# | chr1|    0|
# | chr1|    1|
# | chr1|    2|
# | chr1|    3|
# | chr1|    4|
# +-----+-----+
# only showing top 5 rows

# %%
spark_dnase.printSchema()
# Out:
# root
#  |-- index: long (nullable = true)
#  |-- chrom: string (nullable = true)
#  |-- start: long (nullable = true)
#  |-- end: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- score: long (nullable = true)
#  |-- strand: string (nullable = true)
#  |-- thickStart: double (nullable = true)
#  |-- thickEnd: double (nullable = true)
#  |-- rgb: long (nullable = true)

# %%
spark_chip_seq.filter(spark_chip_seq["rgb"]>100).show()
# Out:
# +-----+-----+---------+---------+----+-----+------+----------+--------+-----+
# |index|chrom|    start|      end|name|score|strand|thickStart|thickEnd|  rgb|
# +-----+-----+---------+---------+----+-----+------+----------+--------+-----+
# |    0| chrX| 10087209| 10088161|   .| 1000|     .|  91.15329|   300.0|300.0|
# |    1|chr12| 32907970| 32909598|   .| 1000|     .|  76.52205|   300.0|300.0|
# |    2|chr12| 50360675| 50361606|   .| 1000|     .| 149.86319|   300.0|300.0|
# |    3|chr12| 56617729| 56618612|   .| 1000|     .| 180.71755|   300.0|300.0|
# |    4|chr12| 82751977| 82753177|   .| 1000|     .| 108.63797|   300.0|300.0|
# |    5|chr12|122231602|122233291|   .| 1000|     .| 122.64868|   300.0|300.0|
# |    6|chr11|   189544|   190474|   .| 1000|     .| 118.98055|   300.0|300.0|
# |    7|chr11| 58938845| 58939735|   .| 1000|     .| 138.27267|   300.0|300.0|
# |    8|chr11| 62553854| 62555271|   .| 1000|     .| 136.69627|   300.0|300.0|
# |    9|chr11| 64780906| 64782157|   .| 1000|     .| 189.39302|   300.0|300.0|
# |   10|chr11| 94884117| 94885485|   .| 1000|     .|  97.15762|   300.0|300.0|
# |   11|chr11|118560416|118561259|   .| 1000|     .| 204.69186|   300.0|300.0|
# |   12|chr10| 71905146| 71907116|   .| 1000|     .|  74.68619|   300.0|300.0|
# |   13|chr10| 90694539| 90695655|   .| 1000|     .| 120.08608|   300.0|300.0|
# |   14|chr17|  8286405|  8287223|   .| 1000|     .| 214.70381|   300.0|300.0|
# |   15|chr17| 39804097| 39805278|   .| 1000|     .| 165.04069|   300.0|300.0|
# |   16|chr17| 44270087| 44272817|   .| 1000|     .|  53.24314|   300.0|300.0|
# |   17|chr16|  2389943|  2391233|   .| 1000|     .| 625.85558|   300.0|300.0|
# |   18|chr16| 30103139| 30104236|   .| 1000|     .| 111.99521|   300.0|300.0|
# |   19|chr16| 47176422| 47178603|   .| 1000|     .| 177.43554|   300.0|300.0|
# +-----+-----+---------+---------+----+-----+------+----------+--------+-----+
# only showing top 20 rows

# %% [markdown]
# ## 2.- Data modify

# %% [markdown]
# ### Funciones Funciones definidas por el usuario (UDF)

# %% [markdown]
# **Steps**:
#
# * Creating a UDF
# * Used
#
# [More examples](https://sparkbyexamples.com/pyspark/pyspark-udf-user-defined-function/)

# %%
from pyspark.sql.types import StringType
from pyspark.sql.functions import col

@udf(returnType=StringType()) 
def upperCase(str):
    return str.upper()

spark_chip_seq.withColumn("Upper chrom", upperCase(col("chrom"))).show(truncate=False)
# Out:
# +-----+-----+---------+---------+----+-----+------+----------+--------+-----+-----------+
# |index|chrom|start    |end      |name|score|strand|thickStart|thickEnd|rgb  |Upper chrom|
# +-----+-----+---------+---------+----+-----+------+----------+--------+-----+-----------+
# |0    |chrX |10087209 |10088161 |.   |1000 |.     |91.15329  |300.0   |300.0|CHRX       |
# |1    |chr12|32907970 |32909598 |.   |1000 |.     |76.52205  |300.0   |300.0|CHR12      |
# |2    |chr12|50360675 |50361606 |.   |1000 |.     |149.86319 |300.0   |300.0|CHR12      |
# |3    |chr12|56617729 |56618612 |.   |1000 |.     |180.71755 |300.0   |300.0|CHR12      |
# |4    |chr12|82751977 |82753177 |.   |1000 |.     |108.63797 |300.0   |300.0|CHR12      |
# |5    |chr12|122231602|122233291|.   |1000 |.     |122.64868 |300.0   |300.0|CHR12      |
# |6    |chr11|189544   |190474   |.   |1000 |.     |118.98055 |300.0   |300.0|CHR11      |
# |7    |chr11|58938845 |58939735 |.   |1000 |.     |138.27267 |300.0   |300.0|CHR11      |
# |8    |chr11|62553854 |62555271 |.   |1000 |.     |136.69627 |300.0   |300.0|CHR11      |
# |9    |chr11|64780906 |64782157 |.   |1000 |.     |189.39302 |300.0   |300.0|CHR11      |
# |10   |chr11|94884117 |94885485 |.   |1000 |.     |97.15762  |300.0   |300.0|CHR11      |
# |11   |chr11|118560416|118561259|.   |1000 |.     |204.69186 |300.0   |300.0|CHR11      |
# |12   |chr10|71905146 |71907116 |.   |1000 |.     |74.68619  |300.0   |300.0|CHR10      |
# |13   |chr10|90694539 |90695655 |.   |1000 |.     |120.08608 |300.0   |300.0|CHR10      |
# |14   |chr17|8286405  |8287223  |.   |1000 |.     |214.70381 |300.0   |300.0|CHR17      |
# |15   |chr17|39804097 |39805278 |.   |1000 |.     |165.04069 |300.0   |300.0|CHR17      |
# |16   |chr17|44270087 |44272817 |.   |1000 |.     |53.24314  |300.0   |300.0|CHR17      |
# |17   |chr16|2389943  |2391233  |.   |1000 |.     |625.85558 |300.0   |300.0|CHR16      |
# |18   |chr16|30103139 |30104236 |.   |1000 |.     |111.99521 |300.0   |300.0|CHR16      |
# |19   |chr16|47176422 |47178603 |.   |1000 |.     |177.43554 |300.0   |300.0|CHR16      |
# +-----+-----+---------+---------+----+-----+------+----------+--------+-----+-----------+
# only showing top 20 rows

# %%
@udf(returnType=StringType()) 
def removeLetters(str):
    return str.replace('chr', '')

spark_chip_seq.withColumn("Upper chrom", removeLetters(col("chrom"))).show(truncate=False)
# Out:
# +-----+-----+---------+---------+----+-----+------+----------+--------+-----+-----------+
# |index|chrom|start    |end      |name|score|strand|thickStart|thickEnd|rgb  |Upper chrom|
# +-----+-----+---------+---------+----+-----+------+----------+--------+-----+-----------+
# |0    |chrX |10087209 |10088161 |.   |1000 |.     |91.15329  |300.0   |300.0|X          |
# |1    |chr12|32907970 |32909598 |.   |1000 |.     |76.52205  |300.0   |300.0|12         |
# |2    |chr12|50360675 |50361606 |.   |1000 |.     |149.86319 |300.0   |300.0|12         |
# |3    |chr12|56617729 |56618612 |.   |1000 |.     |180.71755 |300.0   |300.0|12         |
# |4    |chr12|82751977 |82753177 |.   |1000 |.     |108.63797 |300.0   |300.0|12         |
# |5    |chr12|122231602|122233291|.   |1000 |.     |122.64868 |300.0   |300.0|12         |
# |6    |chr11|189544   |190474   |.   |1000 |.     |118.98055 |300.0   |300.0|11         |
# |7    |chr11|58938845 |58939735 |.   |1000 |.     |138.27267 |300.0   |300.0|11         |
# |8    |chr11|62553854 |62555271 |.   |1000 |.     |136.69627 |300.0   |300.0|11         |
# |9    |chr11|64780906 |64782157 |.   |1000 |.     |189.39302 |300.0   |300.0|11         |
# |10   |chr11|94884117 |94885485 |.   |1000 |.     |97.15762  |300.0   |300.0|11         |
# |11   |chr11|118560416|118561259|.   |1000 |.     |204.69186 |300.0   |300.0|11         |
# |12   |chr10|71905146 |71907116 |.   |1000 |.     |74.68619  |300.0   |300.0|10         |
# |13   |chr10|90694539 |90695655 |.   |1000 |.     |120.08608 |300.0   |300.0|10         |
# |14   |chr17|8286405  |8287223  |.   |1000 |.     |214.70381 |300.0   |300.0|17         |
# |15   |chr17|39804097 |39805278 |.   |1000 |.     |165.04069 |300.0   |300.0|17         |
# |16   |chr17|44270087 |44272817 |.   |1000 |.     |53.24314  |300.0   |300.0|17         |
# |17   |chr16|2389943  |2391233  |.   |1000 |.     |625.85558 |300.0   |300.0|16         |
# |18   |chr16|30103139 |30104236 |.   |1000 |.     |111.99521 |300.0   |300.0|16         |
# |19   |chr16|47176422 |47178603 |.   |1000 |.     |177.43554 |300.0   |300.0|16         |
# +-----+-----+---------+---------+----+-----+------+----------+--------+-----+-----------+
# only showing top 20 rows

# %%
keys = spark.sql("""
SELECT chrom
FROM temp_chip_seq
GROUP BY chrom
""").rdd.map(lambda x: x[0]).collect()

# %%
dictionary = {key: value for key, value in zip(keys, range(0, len(keys)))}

# %%
@udf(returnType=StringType()) 
def replaceByCode(str):
    return dictionary[str]

spark_chip_seq.withColumn("Code", replaceByCode(col("chrom"))).show(truncate=False)
# Out:
# +-----+-----+---------+---------+----+-----+------+----------+--------+-----+----+
# |index|chrom|start    |end      |name|score|strand|thickStart|thickEnd|rgb  |Code|
# +-----+-----+---------+---------+----+-----+------+----------+--------+-----+----+
# |0    |chrX |10087209 |10088161 |.   |1000 |.     |91.15329  |300.0   |300.0|6   |
# |1    |chr12|32907970 |32909598 |.   |1000 |.     |76.52205  |300.0   |300.0|0   |
# |2    |chr12|50360675 |50361606 |.   |1000 |.     |149.86319 |300.0   |300.0|0   |
# |3    |chr12|56617729 |56618612 |.   |1000 |.     |180.71755 |300.0   |300.0|0   |
# |4    |chr12|82751977 |82753177 |.   |1000 |.     |108.63797 |300.0   |300.0|0   |
# |5    |chr12|122231602|122233291|.   |1000 |.     |122.64868 |300.0   |300.0|0   |
# |6    |chr11|189544   |190474   |.   |1000 |.     |118.98055 |300.0   |300.0|16  |
# |7    |chr11|58938845 |58939735 |.   |1000 |.     |138.27267 |300.0   |300.0|16  |
# |8    |chr11|62553854 |62555271 |.   |1000 |.     |136.69627 |300.0   |300.0|16  |
# |9    |chr11|64780906 |64782157 |.   |1000 |.     |189.39302 |300.0   |300.0|16  |
# |10   |chr11|94884117 |94885485 |.   |1000 |.     |97.15762  |300.0   |300.0|16  |
# |11   |chr11|118560416|118561259|.   |1000 |.     |204.69186 |300.0   |300.0|16  |
# |12   |chr10|71905146 |71907116 |.   |1000 |.     |74.68619  |300.0   |300.0|3   |
# |13   |chr10|90694539 |90695655 |.   |1000 |.     |120.08608 |300.0   |300.0|3   |
# |14   |chr17|8286405  |8287223  |.   |1000 |.     |214.70381 |300.0   |300.0|17  |
# |15   |chr17|39804097 |39805278 |.   |1000 |.     |165.04069 |300.0   |300.0|17  |
# |16   |chr17|44270087 |44272817 |.   |1000 |.     |53.24314  |300.0   |300.0|17  |
# |17   |chr16|2389943  |2391233  |.   |1000 |.     |625.85558 |300.0   |300.0|21  |
# |18   |chr16|30103139 |30104236 |.   |1000 |.     |111.99521 |300.0   |300.0|21  |
# |19   |chr16|47176422 |47178603 |.   |1000 |.     |177.43554 |300.0   |300.0|21  |
# +-----+-----+---------+---------+----+-----+------+----------+--------+-----+----+
# only showing top 20 rows
